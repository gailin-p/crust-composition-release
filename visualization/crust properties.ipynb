# %%
using Plots; gr();

include("../src/crustDistribution.jl")
include("../src/utilities.jl")
# Out:
# Loading crust information from file ../resources/crustDistribution.jld
# areaAverage

# %%
g = globe(crustDistribution.all_lats, crustDistribution.all_longs, 
    fill(1.0, length(crustDistribution.all_lats))); 
heatmap(g)

# %%
d = Dict{Tuple{Float64,Float64},Float64}()
for i in 1:length(crustDistribution.all_lats)
    d[(crustDistribution.all_lats[i],crustDistribution.all_longs[i])] = 1.0
end

# %%
d[(-17.0,-17.0)]
# Out:
# KeyError: key (-17.0, -17.0) not found
#
# Stacktrace:
#  [1] getindex(h::Dict{Tuple{Float64, Float64}, Float64}, key::Tuple{Float64, Float64})
#    @ Base ./dict.jl:482
#  [2] top-level scope
#    @ In[8]:1
#  [3] eval
#    @ ./boot.jl:360 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

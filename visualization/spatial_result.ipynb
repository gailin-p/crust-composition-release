# %%
using DelimitedFiles
using Plots; gr();

include("../src/utilities.jl")
# Out:
# areaAverage

# %%
dat, head = readdlm("../data/base_single/base_large/results-upper.csv", ',', header=true)
head = head[:];

# %%
dat_mid, _ = readdlm("../data/base_single/base/results-middle.csv", ',', header=true)
dat_low, _ = readdlm("../data/base_single/base/results-lower.csv", ',', header=true);

# %%
lat_i = findfirst(isequal("sample_lat"),head)
long_i = findfirst(isequal("sample_long"),head)
si_i = findfirst(isequal("SiO2"),head)
ave_lat, ave_long, ave_si = areaAverage(dat[:,lat_i], dat[:,long_i], dat[:,si_i])
# Out:
# ([-23.0, -6.0, -23.0, 17.0, -83.0, -37.0, 55.0, -81.0, 19.0, 38.0  …  -79.0, 55.0, 16.0, -29.0, 44.0, 63.0, 52.0, -88.0, 34.0, 66.0], [134.0, 15.0, 46.0, 12.0, 102.0, -63.0, -125.0, 79.0, -90.0, -105.0  …  -84.0, -66.0, -11.0, -50.0, 74.0, -138.0, 116.0, -74.0, -85.0, 20.0], [56.53496536312853, 54.284955806451656, 56.100328629441606, 56.94718324324327, 58.26351181818182, 58.51796131250004, 57.82968130434783, 60.90195685714285, 57.76303266304343, 60.986931091954034  …  56.567945, 60.617112526315786, 57.44671851282054, 56.335949644970434, 59.02554987878789, 62.29304170454546, 61.80166984000003, 59.9774, 55.365848354430376, 58.869548481012636])

# %%
lat_i = findfirst(isequal("sample_lat"),head)
long_i = findfirst(isequal("sample_long"),head)
si_i = findfirst(isequal("SiO2"),head)

u_lat, u_long, u_av, u_var = areaAverage(dat[:,lat_i], dat[:,long_i], dat[:,si_i], return_std=true)
m_lat, m_long, m_av, m_var = areaAverage(dat_mid[:,lat_i], dat_mid[:,long_i], dat_mid[:,si_i], return_std=true);
l_lat, l_long, l_av, l_var= areaAverage(dat_low[:,lat_i], dat_low[:,long_i], dat_low[:,si_i], return_std=true);

g_upper = globe(u_lat, u_long, u_av)
g_mid = globe(m_lat, m_long, m_av)
g_low = globe(l_lat, l_long, l_av)

g_low[1,1] = 75 # force scale same as g_upper and g_mid
        
v_upper = globe(u_lat, u_long, u_var)
v_mid = globe(m_lat, m_long, m_var)
v_low = globe(l_lat, l_long, l_var);

v_upper[1,1] = 12.5
v_mid[1,1] = 12.5
v_low[1,1] = 12.5


v_upper[v_upper .> 13] .= NaN
v_mid[v_mid .> 13] .= NaN
v_low[v_low .> 13] .= NaN
# Out:
# 21-element view(::Vector{Float64}, [835, 4291, 8094, 13496, 16345, 18497, 19640, 20027, 23757, 25584  …  28979, 29709, 30699, 34007, 40104, 42590, 45225, 47200, 51460, 51995]) with eltype Float64:
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN

# %%
# Add an 80 and a 40 to all maps
g_upper[1,1] = 80
g_upper[1,2] = 40
g_mid[1,1] = 80
g_mid[1,2] = 40
g_low[1,1] = 80
g_low[1,2] = 40
# Out:
# 40

# %%
h1 = heatmap(g_upper, framestyle=:box, xticks=false, yticks=false, colorbar=false)
h2 = heatmap(g_mid,framestyle=:box, xticks=false, yticks=false, colorbar=false)
h3 = heatmap(g_low, framestyle=:box, xticks=false, yticks=false, colorbar=true)

v1 = heatmap(v_upper, framestyle=:box, color=:speed, xticks=false, yticks=false, colorbar=false)
v2 = heatmap(v_mid,framestyle=:box, color=:speed, xticks=false, yticks=false, colorbar=false)
v3 = heatmap(v_low, framestyle=:box, color=:speed, xticks=false, yticks=false, colorbar=true)

plot(h1,h2, h3, v1, v2, v3, layout=(2,3), size=(700,300), dpi=300)
#savefig("../../thesis/figures/spatial_result_colorbar.png")

# %%
histogram([Iterators.flatten(v_upper)...])

# %%
surface, head = readdlm("../data/base/bsr_ignmajors_1.csv", ',', header=true)
head = head[:];

# %%
head
lat_i = findfirst(isequal("Latitude"),head)
long_i = findfirst(isequal("Longitude"),head)
si_i = findfirst(isequal("SiO2"),head)
ave_surface_lat, ave_surface_long, ave_surface_si = 
    areaAverage(surface[:,lat_i], surface[:,long_i], surface[:,si_i]);

# %%
# map upper crust to surface averages 
d = Dict{Tuple{Float64,Float64},Tuple{Float64,Float64}}()
for i in 1:length(ave_surface_lat)
    d[(ave_surface_lat[i],ave_surface_long[i])] = (ave_surface_si[i], NaN)
end
# add estimated upper crust vals 
for i in 1:length(ave_lat)
    if (ave_lat[i],ave_long[i]) in keys(d)
        d[(ave_lat[i],ave_long[i])] = (d[(ave_lat[i],ave_long[i])][1], ave_si[i])
    end
end
# remove nans 
for k in keys(d)
    if isnan(sum(d[k]))
        pop!(d,k)
    end
end

# %%
vals = values(d)
scatter([e[1] for e in vals], [e[2] for e in vals])

# %%
g = globe(areaAverage(surface[:,lat_i], surface[:,long_i], surface[:,si_i])...);
heatmap(g)

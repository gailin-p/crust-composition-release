# %%
using StatGeochem
using Plots; gr();
using NetCDF

include("../src/invertData.jl")
# Out:
# getAllSeismic

# %%
f1 = "../data/seismic/csem-north-america-2019.12.01.nc"
f2 = "../data/seismic/DNA13_percent.nc"
ncinfo(f2)
# Out:
# ##### NetCDF File #####
#
# /Users/gailin/dartmouth/crustal_structure/runPerplexBatchVp/data/seismic/DNA13_percent.nc
#
# ##### Dimensions #####
#
# Name                                                Length
# --------------------------------------------------------------------------------
# depth                                               129
# latitude                                            55
# longitude                                           109
#
# ##### Variables #####
#
# Name                            Type            Dimensions
# --------------------------------------------------------------------------------
# depth                           FLOAT           depth
# latitude                        FLOAT           latitude
# vp                              FLOAT           longitude latitude depth
# longitude                       FLOAT           longitude
# vsh                             FLOAT           longitude latitude depth
# ...

# %%
vsv = ncread(f1, "vsv")
vsh = ncread(f1, "vsh");

# %%
heatmap(vsv[:,:,4]./vsh[:,:,4])

# %%
vsv2 = ncread(f2, "vsv")
vsh2= ncread(f2, "vsh");

# %%
heatmap(vsv2[:,:,2]./vsh2[:,:,2])
